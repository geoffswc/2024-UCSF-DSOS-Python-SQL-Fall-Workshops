# %%
print("hello")
# Out:
# hello

# %%
print("good morning")
# Out:
# good morning

# %%
# prompt: print the phrases hello world and good morning to the screen

print("hello world")
print("good morning")
# Out:
# hello world
# good morning

# %%
#https://raw.githubusercontent.com/mdcollab/covidclinicaldata/refs/heads/master/data/04-07_carbonhealth_and_braidhealth.csv

# %%
import pandas as pd

# %%
pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %%
df_covid_04_07 = pd.read_csv("https://raw.githubusercontent.com/mdcollab/covidclinicaldata/refs/heads/master/data/04-07_carbonhealth_and_braidhealth.csv")

# %%
df_covid_04_07.tail(5)
# Out:
#      batch_date             test_name       swab_type covid19_test_results  \
# 730  2020-04-07       SARS-CoV-2, NAA  Nasopharyngeal             Negative
# 731  2020-04-07  SARS COV 2 RNA RTPCR   Oropharyngeal             Negative
# 732  2020-04-07       SARS-CoV-2, NAA  Nasopharyngeal             Negative
# 733  2020-04-07  SARS CoV w/CoV 2 RNA   Oropharyngeal             Negative
# 734  2020-04-07   Rapid COVID-19 Test           Nasal             Negative
#
#      age high_risk_exposure_occupation high_risk_interactions  diabetes  \
# 730   53                          True                   True      True
# 731   46                         False                    NaN     False
# 732   33                         False                    NaN     False
# 733   53                         False                   True     False
# 734   30                          True                   True     False
#
#        chd    htn  cancer  asthma   copd  autoimmune_dis  smoker  temperature  \
# ...

# %%
df_covid_04_07.columns
# Out:
# Index(['batch_date', 'test_name', 'swab_type', 'covid19_test_results', 'age',
#        'high_risk_exposure_occupation', 'high_risk_interactions', 'diabetes',
#        'chd', 'htn', 'cancer', 'asthma', 'copd', 'autoimmune_dis', 'smoker',
#        'temperature', 'pulse', 'sys', 'dia', 'rr', 'sats', 'rapid_flu_results',
#        'rapid_strep_results', 'ctab', 'labored_respiration', 'rhonchi',
#        'wheezes', 'days_since_symptom_onset', 'cough', 'cough_severity',
#        'fever', 'sob', 'sob_severity', 'diarrhea', 'fatigue', 'headache',
#        'loss_of_smell', 'loss_of_taste', 'runny_nose', 'muscle_sore',
#        'sore_throat', 'cxr_findings', 'cxr_impression', 'cxr_label',
#        'cxr_link', 'er_referral'],
#       dtype='object')

# %%
df_covid_04_07.describe(include="all")["high_risk_interactions"]
# Out:
# count      284
# unique       2
# top       True
# freq       152
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
# Name: high_risk_interactions, dtype: object
