# %%
print("hello")
# Out:
# hello

# %%
# prompt: create a python dictionary to hold the caffeine content listed on this web page: https://www.mayoclinic.org/healthy-lifestyle/nutrition-and-healthy-eating/in-depth/caffeine/art-20049372 please make sure the dictionary is nested limit the data to what is on the page

caffeine_content = {
    "Beverages": {
        "Brewed coffee": {"8-ounce cup": "80-100 milligrams"},
        "Instant coffee": {"8-ounce cup": "60-80 milligrams"},
        "Espresso": {"1-ounce shot": "60 milligrams"},
        "Decaffeinated coffee": {"8-ounce cup": "2-5 milligrams"},
        "Tea": {
            "Black tea": {"8-ounce cup": "40-70 milligrams"},
            "Green tea": {"8-ounce cup": "20-45 milligrams"},
            "Herbal tea": {"Typically contains": "No caffeine"}
        },
        "Soft drinks and energy drinks": {
            "Cola": {"12-ounce can": "30-40 milligrams"},
            "Energy drink": {"8-ounce can": "80-100 milligrams"}
        },
        "Chocolate milk": {"8-ounce glass": "2-6 milligrams"}
    },
    "Foods": {
        "Dark chocolate": {"1-ounce serving": "12 milligrams"},
        "Milk chocolate": {"1-ounce serving": "6 milligrams"}
    }
}
print(caffeine_content)
