# %%
# prompt: download the document at https://download.industrydocuments.ucsf.edu/s/g/f/v/sgfv0291/sgfv0291.pdf then use py-tesseract to extract the text from it

# !pip install pytesseract Pillow
# !apt-get install tesseract-ocr

import requests
from PIL import Image
import pytesseract
import os

# Download the PDF
url = "https://download.industrydocuments.ucsf.edu/s/g/f/v/sgfv0291/sgfv0291.pdf"
response = requests.get(url, stream=True)
response.raise_for_status()  # Raise an exception for bad status codes

filename = "sgfv0291.pdf"
with open(filename, "wb") as pdf_file:
    for chunk in response.iter_content(chunk_size=8192):
        pdf_file.write(chunk)

# Convert PDF to image (you might need to install poppler-utils)
# !apt-get install poppler-utils
# !pdftoppm sgfv0291.pdf output

# OCR the image
image_path = "output-1.ppm"  # Assuming the first page is named output-1.ppm
try:
    img = Image.open(image_path)
    text = pytesseract.image_to_string(img)
    print(text)

except FileNotFoundError:
  print(f"Error: Could not find image file {image_path}. Check if pdftoppm created the image successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

# Clean up the downloaded files (optional)
os.remove(filename)
# Clean up the generated images (optional, but recommended)
# !rm output-*.ppm
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (6,494 kB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123652 files and directories currently installed.)
# ...

# %%
print(text)
# Out:
# To: gal@juul.com[gal@juul.com]
# From: U.S. Food and Drug Administration
# Sent: Tue 3/26/2019 12:16:49 PM
#
# Importance: Normal
# Subject: Henry Avocado Recalls Whole Avocados Because Of Possible Health Risk
# Received: Tue 3/26/2019 12:16:49 PM
#
# if your email program has trouble displaying this email, view itas a web page
#
#
#
#
#
# Henry Avocado Recalls Whole Avocados Because Of Possible Health Risk
#
# Henry Avocado Corporation is voluntarily recalling California-grown whole avocados sold in
# bulk at retail stores because they have the potential to be contaminated with Listeria
# monocytogenes. Henry Avocado is issuing this voluntary recall out of an abundance of caution
# due to positive test results on environmental samples taken during a routine government
# inspection at its California packing facility. There are no reported illnesses associated with this
# recall.
#
# Listeria monocytogenes is an organism which can cause serious and sometimes fatal
# ...
